# %% [markdown]
# <a href="https://colab.research.google.com/github/zulker0010/calorie_prediction-model/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as p
train_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML Notebooks/calorie_burn_models/train.csv')
train_df.head()
# Out:
#    id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp  Calories
# 0   0    male   36   189.0    82.0      26.0       101.0       41.0     150.0
# 1   1  female   64   163.0    60.0       8.0        85.0       39.7      34.0
# 2   2  female   51   161.0    64.0       7.0        84.0       39.8      29.0
# 3   3    male   20   192.0    90.0      25.0       105.0       40.7     140.0
# 4   4  female   38   166.0    61.0      25.0       102.0       40.6     146.0

# %%
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ML Notebooks/calorie_burn_models/test.csv')
test_df.head()
# Out:
#        id     Sex  Age  Height  Weight  Duration  Heart_Rate  Body_Temp
# 0  750000    male   45   177.0    81.0       7.0        87.0       39.8
# 1  750001    male   26   200.0    97.0      20.0       101.0       40.5
# 2  750002  female   29   188.0    85.0      16.0       102.0       40.4
# 3  750003  female   39   172.0    73.0      20.0       107.0       40.6
# 4  750004  female   30   173.0    67.0      16.0        94.0       40.5

# %%
#scatterplot to see correlation of each variable with calories
